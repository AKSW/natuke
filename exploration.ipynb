# %%
import pandas as pd
path = 'path-to-data-repository'

# %%
df = pd.read_parquet('{}file-name_query03-05.parquet'.format(path))
df
# Out:
#                                  doi             bioActivity  \
# 0     10.1016/j.biortech.2010.01.041  Inhibition of Protease
# 1     10.1016/j.biortech.2010.01.041  Inhibition of Protease
# 2     10.1016/j.biortech.2010.01.041  Inhibition of Protease
# 3     10.1016/j.biortech.2010.01.041               Antiviral
# 4     10.1016/j.biortech.2010.01.041               Antiviral
# ...                              ...                     ...
# 2299   10.1016/S0031-9422(00)94671-5
# 2300   10.1016/S0031-9422(00)80444-6
# 2301             10.1021/np50032a021
# 2302   10.1016/S0031-9422(00)83467-6
# 2303    10.1016/0031-9422(80)83208-0
#
#                       collectionSpecie collectionSite  \
# 0     Piper crassinervium (Piperaceae)  Araraquara/SP
# 1     Piper crassinervium (Piperaceae)  Araraquara/SP
# 2     Piper crassinervium (Piperaceae)  Araraquara/SP
# 3     Piper crassinervium (Piperaceae)  Araraquara/SP
# 4     Piper crassinervium (Piperaceae)  Araraquara/SP
# ...

# %%
[len(df.name.unique()), len(df.bioActivity.unique()), len(df.collectionSpecie.unique()), len(df.collectionSite.unique()), len(df.collectionType.unique())]
# Out:
# [446, 34, 116, 52, 6]
